# %%
from pymorphit.pymorphit import Morphit
import re
import itertools
import random as rd

# %% [markdown]
# ## Obiettivo: generare un set di frasi del tipo "dove si trovano le mie bollette"
# ### Scrivo delle liste-vocabolario immaginando possibili alternative lessicali

# %%
mia = ["mia", ""]
bolletta = ["bolletta", "bollette"]
essere = ["sono", "stare", "si* trova"] # l'asterisco permette di segnalare a pymorphit che la parola precedente è invariante

# %% [markdown]
# ### Posso interrogare wordnet italiano se non mi vengono in mente sinonimi

# %%
def synonyms(lemma):
    from nltk.corpus import wordnet as wn
    synmorph = {}
    wnet_lemmas = wn.lemmas(lemma, lang="ita")
    for index, wnet_lemma in enumerate(wnet_lemmas):
        syns = wnet_lemma.synset()
        m = re.findall("\'([^']*)\'", str(syns))
        synmorph.update({m[0]: syns.lemma_names(lang="ita")})
    return synmorph


synonyms("bolletta")
# Out:
# {'bill.n.02': ['bolletta', 'bulletta', 'conto', 'fattura'],
#  'receipt.n.02': ['bolletta',
#   'bulletta',
#   'contromarca',
#   'polizza',
#   'quetazione',
#   'quietanza',
#   'quietazione',
#   'ricevuta',
#   'ricevuta_fiscale',
#   'scontrino',
#   'ticket']}

# %% [markdown]
# ### "fattura" per esempio è un buon sinonimo di 'bolletta', lo aggiungo alla mia variabile

# %%
bolletta.append("fattura")

# %% [markdown]
# ## Le mie liste-vocabolario sono un po' piccole, ma vediamo quante combinazioni posso generare a partire da queste. Tante sono le combinazioni, tante le frasi uniche che posso generare!
# ### Scrivo una semplice funzione con itertools, che prende in argomento le mie variabili (nell'ordine naturale della frase)

# %%
def combo(*args):
    slots = [i for i in args]
    return [combo for combo in itertools.product(*slots)]

combos1 = combo(essere, mia, bolletta)
print(f'Le possibili combinazioni sono in tutto {len(combos1)}')
print()
combos1
# Out:
# Le possibili combinazioni sono in tutto 18
# [('sono', 'mia', 'bolletta'),
#  ('sono', 'mia', 'bollette'),
#  ('sono', 'mia', 'fattura'),
#  ('sono', '', 'bolletta'),
#  ('sono', '', 'bollette'),
#  ('sono', '', 'fattura'),
#  ('stare', 'mia', 'bolletta'),
#  ('stare', 'mia', 'bollette'),
#  ('stare', 'mia', 'fattura'),
#  ('stare', '', 'bolletta'),
#  ('stare', '', 'bollette'),
#  ('stare', '', 'fattura'),
#  ('si* trova', 'mia', 'bolletta'),
#  ('si* trova', 'mia', 'bollette'),
#  ('si* trova', 'mia', 'fattura'),
#  ('si* trova', '', 'bolletta'),
#  ('si* trova', '', 'bollette'),
#  ('si* trova', '', 'fattura')]

# %% [markdown]
# ### La lista 'bolletta' contiene le parole destinate a essere la testa della frase, ossia la parola alla quale tutte le altre si devono accordare per generare una frase morfologicamente corretta
# ### Qui entra in gioco Pymorphit: per ogni combinazione viene inizializzato l'oggetto Morphit corrispondente alla testa. Per ragioni di efficienza, le parole già viste da Morphit vengono stoccate (funzione store)

# %%
seen = {}

def store(w, seen=seen):
    if w not in seen.keys():
        seen[w] = Morphit(w, "NOUN")
    return seen[w]

# %% [markdown]
# ## Adesso ciclo sulla lista di combinazioni e genero le frasi, tutte correttamente concordate con i metodi di Pymorphit

# %%
gen_sents = []

for essere, mia, bill in combos1:
    
    # h sta per head: la parola a cui si accordano le altri parti del discorso
    h = store(bill)
    
    # i verbi di tipo "essere" di accordano al soggetto "bolletta" e cosivvia. 
    gen_sents.append(f'dove {h.agr(essere)} {h.article()} {h.agr(mia)} {h.word}?')

# %%
gen_sents
# Out:
# ['dove é la mia bolletta?',
#  'dove sono le mie bollette?',
#  'dove é la mia fattura?',
#  'dove é la  bolletta?',
#  'dove sono le  bollette?',
#  'dove é la  fattura?',
#  'dove sta la mia bolletta?',
#  'dove stanno le mie bollette?',
#  'dove sta la mia fattura?',
#  'dove sta la  bolletta?',
#  'dove stanno le  bollette?',
#  'dove sta la  fattura?',
#  'dove si trova la mia bolletta?',
#  'dove si trovano le mie bollette?',
#  'dove si trova la mia fattura?',
#  'dove si trova la  bolletta?',
#  'dove si trovano le  bollette?',
#  'dove si trova la  fattura?']

# %% [markdown]
# ### Ci sono un po' di doppi spazi. Puliamo le frasi con una funzione di formattazione

# %%
def formatt(frase):
    punkt1 = re.sub(r'([A-z])( )([,.?!"])',r"\1\3", frase)
    punkt2 = re.sub(r'(\')( )([A-z])',r"\1\3", punkt1)
    formatted = re.sub(r"(^|[.?!])\s*([a-zA-Zè])", lambda p: p.group(0).upper(), punkt2)
    return re.sub(" +"," ", formatted)

[formatt(i) for i in gen_sents]
# Out:
# ['Dove é la mia bolletta?',
#  'Dove sono le mie bollette?',
#  'Dove é la mia fattura?',
#  'Dove é la bolletta?',
#  'Dove sono le bollette?',
#  'Dove é la fattura?',
#  'Dove sta la mia bolletta?',
#  'Dove stanno le mie bollette?',
#  'Dove sta la mia fattura?',
#  'Dove sta la bolletta?',
#  'Dove stanno le bollette?',
#  'Dove sta la fattura?',
#  'Dove si trova la mia bolletta?',
#  'Dove si trovano le mie bollette?',
#  'Dove si trova la mia fattura?',
#  'Dove si trova la bolletta?',
#  'Dove si trovano le bollette?',
#  'Dove si trova la fattura?']

# %% [markdown]
# ## Adesso qualcosa di più elaborato...

# %%
non = ["dove","non"]
trovo = ["trovo", "vedo", "posso vedere"]
mia = ["mia", ""]
bolletta = ["bolletta", "bollette", "fatture"]
su = ["in", "su"]
area = ["area", "spazio"]
clienti = ['riservato', 'clienti*', "personale"]


combos2 = combo(non, trovo, mia, bolletta, su, area, clienti)
print(f'Le possibili combinazioni sono in tutto {len(combos2)}')
combos2
# Out:
# Le possibili combinazioni sono in tutto 432
# [('dove', 'trovo', 'mia', 'bolletta', 'in', 'area', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'in', 'area', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'in', 'area', 'personale'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'in', 'spazio', 'personale'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'su', 'area', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'su', 'area', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'su', 'area', 'personale'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bolletta', 'su', 'spazio', 'personale'),
#  ('dove', 'trovo', 'mia', 'bollette', 'in', 'area', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bollette', 'in', 'area', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bollette', 'in', 'area', 'personale'),
#  ('dove', 'trovo', 'mia', 'bollette', 'in', 'spazio', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bollette', 'in', 'spazio', 'personale'),
#  ('dove', 'trovo', 'mia', 'bollette', 'su', 'area', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bollette', 'su', 'area', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bollette', 'su', 'area', 'personale'),
#  ('dove', 'trovo', 'mia', 'bollette', 'su', 'spazio', 'riservato'),
#  ('dove', 'trovo', 'mia', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'bollette', 'su', 'spazio', 'personale'),
#  ('dove', 'trovo', 'mia', 'fatture', 'in', 'area', 'riservato'),
#  ('dove', 'trovo', 'mia', 'fatture', 'in', 'area', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'fatture', 'in', 'area', 'personale'),
#  ('dove', 'trovo', 'mia', 'fatture', 'in', 'spazio', 'riservato'),
#  ('dove', 'trovo', 'mia', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'fatture', 'in', 'spazio', 'personale'),
#  ('dove', 'trovo', 'mia', 'fatture', 'su', 'area', 'riservato'),
#  ('dove', 'trovo', 'mia', 'fatture', 'su', 'area', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'fatture', 'su', 'area', 'personale'),
#  ('dove', 'trovo', 'mia', 'fatture', 'su', 'spazio', 'riservato'),
#  ('dove', 'trovo', 'mia', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('dove', 'trovo', 'mia', 'fatture', 'su', 'spazio', 'personale'),
#  ('dove', 'trovo', '', 'bolletta', 'in', 'area', 'riservato'),
#  ('dove', 'trovo', '', 'bolletta', 'in', 'area', 'clienti*'),
#  ('dove', 'trovo', '', 'bolletta', 'in', 'area', 'personale'),
#  ('dove', 'trovo', '', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('dove', 'trovo', '', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('dove', 'trovo', '', 'bolletta', 'in', 'spazio', 'personale'),
#  ('dove', 'trovo', '', 'bolletta', 'su', 'area', 'riservato'),
#  ('dove', 'trovo', '', 'bolletta', 'su', 'area', 'clienti*'),
#  ('dove', 'trovo', '', 'bolletta', 'su', 'area', 'personale'),
#  ('dove', 'trovo', '', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('dove', 'trovo', '', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('dove', 'trovo', '', 'bolletta', 'su', 'spazio', 'personale'),
#  ('dove', 'trovo', '', 'bollette', 'in', 'area', 'riservato'),
#  ('dove', 'trovo', '', 'bollette', 'in', 'area', 'clienti*'),
#  ('dove', 'trovo', '', 'bollette', 'in', 'area', 'personale'),
#  ('dove', 'trovo', '', 'bollette', 'in', 'spazio', 'riservato'),
#  ('dove', 'trovo', '', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('dove', 'trovo', '', 'bollette', 'in', 'spazio', 'personale'),
#  ('dove', 'trovo', '', 'bollette', 'su', 'area', 'riservato'),
#  ('dove', 'trovo', '', 'bollette', 'su', 'area', 'clienti*'),
#  ('dove', 'trovo', '', 'bollette', 'su', 'area', 'personale'),
#  ('dove', 'trovo', '', 'bollette', 'su', 'spazio', 'riservato'),
#  ('dove', 'trovo', '', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('dove', 'trovo', '', 'bollette', 'su', 'spazio', 'personale'),
#  ('dove', 'trovo', '', 'fatture', 'in', 'area', 'riservato'),
#  ('dove', 'trovo', '', 'fatture', 'in', 'area', 'clienti*'),
#  ('dove', 'trovo', '', 'fatture', 'in', 'area', 'personale'),
#  ('dove', 'trovo', '', 'fatture', 'in', 'spazio', 'riservato'),
#  ('dove', 'trovo', '', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('dove', 'trovo', '', 'fatture', 'in', 'spazio', 'personale'),
#  ('dove', 'trovo', '', 'fatture', 'su', 'area', 'riservato'),
#  ('dove', 'trovo', '', 'fatture', 'su', 'area', 'clienti*'),
#  ('dove', 'trovo', '', 'fatture', 'su', 'area', 'personale'),
#  ('dove', 'trovo', '', 'fatture', 'su', 'spazio', 'riservato'),
#  ('dove', 'trovo', '', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('dove', 'trovo', '', 'fatture', 'su', 'spazio', 'personale'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'in', 'area', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'in', 'area', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'in', 'area', 'personale'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'in', 'spazio', 'personale'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'su', 'area', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'su', 'area', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'su', 'area', 'personale'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bolletta', 'su', 'spazio', 'personale'),
#  ('dove', 'vedo', 'mia', 'bollette', 'in', 'area', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bollette', 'in', 'area', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bollette', 'in', 'area', 'personale'),
#  ('dove', 'vedo', 'mia', 'bollette', 'in', 'spazio', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bollette', 'in', 'spazio', 'personale'),
#  ('dove', 'vedo', 'mia', 'bollette', 'su', 'area', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bollette', 'su', 'area', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bollette', 'su', 'area', 'personale'),
#  ('dove', 'vedo', 'mia', 'bollette', 'su', 'spazio', 'riservato'),
#  ('dove', 'vedo', 'mia', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'bollette', 'su', 'spazio', 'personale'),
#  ('dove', 'vedo', 'mia', 'fatture', 'in', 'area', 'riservato'),
#  ('dove', 'vedo', 'mia', 'fatture', 'in', 'area', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'fatture', 'in', 'area', 'personale'),
#  ('dove', 'vedo', 'mia', 'fatture', 'in', 'spazio', 'riservato'),
#  ('dove', 'vedo', 'mia', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'fatture', 'in', 'spazio', 'personale'),
#  ('dove', 'vedo', 'mia', 'fatture', 'su', 'area', 'riservato'),
#  ('dove', 'vedo', 'mia', 'fatture', 'su', 'area', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'fatture', 'su', 'area', 'personale'),
#  ('dove', 'vedo', 'mia', 'fatture', 'su', 'spazio', 'riservato'),
#  ('dove', 'vedo', 'mia', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('dove', 'vedo', 'mia', 'fatture', 'su', 'spazio', 'personale'),
#  ('dove', 'vedo', '', 'bolletta', 'in', 'area', 'riservato'),
#  ('dove', 'vedo', '', 'bolletta', 'in', 'area', 'clienti*'),
#  ('dove', 'vedo', '', 'bolletta', 'in', 'area', 'personale'),
#  ('dove', 'vedo', '', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('dove', 'vedo', '', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('dove', 'vedo', '', 'bolletta', 'in', 'spazio', 'personale'),
#  ('dove', 'vedo', '', 'bolletta', 'su', 'area', 'riservato'),
#  ('dove', 'vedo', '', 'bolletta', 'su', 'area', 'clienti*'),
#  ('dove', 'vedo', '', 'bolletta', 'su', 'area', 'personale'),
#  ('dove', 'vedo', '', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('dove', 'vedo', '', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('dove', 'vedo', '', 'bolletta', 'su', 'spazio', 'personale'),
#  ('dove', 'vedo', '', 'bollette', 'in', 'area', 'riservato'),
#  ('dove', 'vedo', '', 'bollette', 'in', 'area', 'clienti*'),
#  ('dove', 'vedo', '', 'bollette', 'in', 'area', 'personale'),
#  ('dove', 'vedo', '', 'bollette', 'in', 'spazio', 'riservato'),
#  ('dove', 'vedo', '', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('dove', 'vedo', '', 'bollette', 'in', 'spazio', 'personale'),
#  ('dove', 'vedo', '', 'bollette', 'su', 'area', 'riservato'),
#  ('dove', 'vedo', '', 'bollette', 'su', 'area', 'clienti*'),
#  ('dove', 'vedo', '', 'bollette', 'su', 'area', 'personale'),
#  ('dove', 'vedo', '', 'bollette', 'su', 'spazio', 'riservato'),
#  ('dove', 'vedo', '', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('dove', 'vedo', '', 'bollette', 'su', 'spazio', 'personale'),
#  ('dove', 'vedo', '', 'fatture', 'in', 'area', 'riservato'),
#  ('dove', 'vedo', '', 'fatture', 'in', 'area', 'clienti*'),
#  ('dove', 'vedo', '', 'fatture', 'in', 'area', 'personale'),
#  ('dove', 'vedo', '', 'fatture', 'in', 'spazio', 'riservato'),
#  ('dove', 'vedo', '', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('dove', 'vedo', '', 'fatture', 'in', 'spazio', 'personale'),
#  ('dove', 'vedo', '', 'fatture', 'su', 'area', 'riservato'),
#  ('dove', 'vedo', '', 'fatture', 'su', 'area', 'clienti*'),
#  ('dove', 'vedo', '', 'fatture', 'su', 'area', 'personale'),
#  ('dove', 'vedo', '', 'fatture', 'su', 'spazio', 'riservato'),
#  ('dove', 'vedo', '', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('dove', 'vedo', '', 'fatture', 'su', 'spazio', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'in', 'area', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'in', 'area', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'in', 'area', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'in', 'spazio', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'su', 'area', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'su', 'area', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'su', 'area', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bolletta', 'su', 'spazio', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'in', 'area', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'in', 'area', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'in', 'area', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'in', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'in', 'spazio', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'su', 'area', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'su', 'area', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'su', 'area', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'su', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'bollette', 'su', 'spazio', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'in', 'area', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'in', 'area', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'in', 'area', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'in', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'in', 'spazio', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'su', 'area', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'su', 'area', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'su', 'area', 'personale'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'su', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', 'mia', 'fatture', 'su', 'spazio', 'personale'),
#  ('dove', 'posso vedere', '', 'bolletta', 'in', 'area', 'riservato'),
#  ('dove', 'posso vedere', '', 'bolletta', 'in', 'area', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bolletta', 'in', 'area', 'personale'),
#  ('dove', 'posso vedere', '', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', '', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bolletta', 'in', 'spazio', 'personale'),
#  ('dove', 'posso vedere', '', 'bolletta', 'su', 'area', 'riservato'),
#  ('dove', 'posso vedere', '', 'bolletta', 'su', 'area', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bolletta', 'su', 'area', 'personale'),
#  ('dove', 'posso vedere', '', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', '', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bolletta', 'su', 'spazio', 'personale'),
#  ('dove', 'posso vedere', '', 'bollette', 'in', 'area', 'riservato'),
#  ('dove', 'posso vedere', '', 'bollette', 'in', 'area', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bollette', 'in', 'area', 'personale'),
#  ('dove', 'posso vedere', '', 'bollette', 'in', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', '', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bollette', 'in', 'spazio', 'personale'),
#  ('dove', 'posso vedere', '', 'bollette', 'su', 'area', 'riservato'),
#  ('dove', 'posso vedere', '', 'bollette', 'su', 'area', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bollette', 'su', 'area', 'personale'),
#  ('dove', 'posso vedere', '', 'bollette', 'su', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', '', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', '', 'bollette', 'su', 'spazio', 'personale'),
#  ('dove', 'posso vedere', '', 'fatture', 'in', 'area', 'riservato'),
#  ('dove', 'posso vedere', '', 'fatture', 'in', 'area', 'clienti*'),
#  ('dove', 'posso vedere', '', 'fatture', 'in', 'area', 'personale'),
#  ('dove', 'posso vedere', '', 'fatture', 'in', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', '', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', '', 'fatture', 'in', 'spazio', 'personale'),
#  ('dove', 'posso vedere', '', 'fatture', 'su', 'area', 'riservato'),
#  ('dove', 'posso vedere', '', 'fatture', 'su', 'area', 'clienti*'),
#  ('dove', 'posso vedere', '', 'fatture', 'su', 'area', 'personale'),
#  ('dove', 'posso vedere', '', 'fatture', 'su', 'spazio', 'riservato'),
#  ('dove', 'posso vedere', '', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('dove', 'posso vedere', '', 'fatture', 'su', 'spazio', 'personale'),
#  ('non', 'trovo', 'mia', 'bolletta', 'in', 'area', 'riservato'),
#  ('non', 'trovo', 'mia', 'bolletta', 'in', 'area', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bolletta', 'in', 'area', 'personale'),
#  ('non', 'trovo', 'mia', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('non', 'trovo', 'mia', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bolletta', 'in', 'spazio', 'personale'),
#  ('non', 'trovo', 'mia', 'bolletta', 'su', 'area', 'riservato'),
#  ('non', 'trovo', 'mia', 'bolletta', 'su', 'area', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bolletta', 'su', 'area', 'personale'),
#  ('non', 'trovo', 'mia', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('non', 'trovo', 'mia', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bolletta', 'su', 'spazio', 'personale'),
#  ('non', 'trovo', 'mia', 'bollette', 'in', 'area', 'riservato'),
#  ('non', 'trovo', 'mia', 'bollette', 'in', 'area', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bollette', 'in', 'area', 'personale'),
#  ('non', 'trovo', 'mia', 'bollette', 'in', 'spazio', 'riservato'),
#  ('non', 'trovo', 'mia', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bollette', 'in', 'spazio', 'personale'),
#  ('non', 'trovo', 'mia', 'bollette', 'su', 'area', 'riservato'),
#  ('non', 'trovo', 'mia', 'bollette', 'su', 'area', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bollette', 'su', 'area', 'personale'),
#  ('non', 'trovo', 'mia', 'bollette', 'su', 'spazio', 'riservato'),
#  ('non', 'trovo', 'mia', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('non', 'trovo', 'mia', 'bollette', 'su', 'spazio', 'personale'),
#  ('non', 'trovo', 'mia', 'fatture', 'in', 'area', 'riservato'),
#  ('non', 'trovo', 'mia', 'fatture', 'in', 'area', 'clienti*'),
#  ('non', 'trovo', 'mia', 'fatture', 'in', 'area', 'personale'),
#  ('non', 'trovo', 'mia', 'fatture', 'in', 'spazio', 'riservato'),
#  ('non', 'trovo', 'mia', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('non', 'trovo', 'mia', 'fatture', 'in', 'spazio', 'personale'),
#  ('non', 'trovo', 'mia', 'fatture', 'su', 'area', 'riservato'),
#  ('non', 'trovo', 'mia', 'fatture', 'su', 'area', 'clienti*'),
#  ('non', 'trovo', 'mia', 'fatture', 'su', 'area', 'personale'),
#  ('non', 'trovo', 'mia', 'fatture', 'su', 'spazio', 'riservato'),
#  ('non', 'trovo', 'mia', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('non', 'trovo', 'mia', 'fatture', 'su', 'spazio', 'personale'),
#  ('non', 'trovo', '', 'bolletta', 'in', 'area', 'riservato'),
#  ('non', 'trovo', '', 'bolletta', 'in', 'area', 'clienti*'),
#  ('non', 'trovo', '', 'bolletta', 'in', 'area', 'personale'),
#  ('non', 'trovo', '', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('non', 'trovo', '', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('non', 'trovo', '', 'bolletta', 'in', 'spazio', 'personale'),
#  ('non', 'trovo', '', 'bolletta', 'su', 'area', 'riservato'),
#  ('non', 'trovo', '', 'bolletta', 'su', 'area', 'clienti*'),
#  ('non', 'trovo', '', 'bolletta', 'su', 'area', 'personale'),
#  ('non', 'trovo', '', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('non', 'trovo', '', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('non', 'trovo', '', 'bolletta', 'su', 'spazio', 'personale'),
#  ('non', 'trovo', '', 'bollette', 'in', 'area', 'riservato'),
#  ('non', 'trovo', '', 'bollette', 'in', 'area', 'clienti*'),
#  ('non', 'trovo', '', 'bollette', 'in', 'area', 'personale'),
#  ('non', 'trovo', '', 'bollette', 'in', 'spazio', 'riservato'),
#  ('non', 'trovo', '', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('non', 'trovo', '', 'bollette', 'in', 'spazio', 'personale'),
#  ('non', 'trovo', '', 'bollette', 'su', 'area', 'riservato'),
#  ('non', 'trovo', '', 'bollette', 'su', 'area', 'clienti*'),
#  ('non', 'trovo', '', 'bollette', 'su', 'area', 'personale'),
#  ('non', 'trovo', '', 'bollette', 'su', 'spazio', 'riservato'),
#  ('non', 'trovo', '', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('non', 'trovo', '', 'bollette', 'su', 'spazio', 'personale'),
#  ('non', 'trovo', '', 'fatture', 'in', 'area', 'riservato'),
#  ('non', 'trovo', '', 'fatture', 'in', 'area', 'clienti*'),
#  ('non', 'trovo', '', 'fatture', 'in', 'area', 'personale'),
#  ('non', 'trovo', '', 'fatture', 'in', 'spazio', 'riservato'),
#  ('non', 'trovo', '', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('non', 'trovo', '', 'fatture', 'in', 'spazio', 'personale'),
#  ('non', 'trovo', '', 'fatture', 'su', 'area', 'riservato'),
#  ('non', 'trovo', '', 'fatture', 'su', 'area', 'clienti*'),
#  ('non', 'trovo', '', 'fatture', 'su', 'area', 'personale'),
#  ('non', 'trovo', '', 'fatture', 'su', 'spazio', 'riservato'),
#  ('non', 'trovo', '', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('non', 'trovo', '', 'fatture', 'su', 'spazio', 'personale'),
#  ('non', 'vedo', 'mia', 'bolletta', 'in', 'area', 'riservato'),
#  ('non', 'vedo', 'mia', 'bolletta', 'in', 'area', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bolletta', 'in', 'area', 'personale'),
#  ('non', 'vedo', 'mia', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('non', 'vedo', 'mia', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bolletta', 'in', 'spazio', 'personale'),
#  ('non', 'vedo', 'mia', 'bolletta', 'su', 'area', 'riservato'),
#  ('non', 'vedo', 'mia', 'bolletta', 'su', 'area', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bolletta', 'su', 'area', 'personale'),
#  ('non', 'vedo', 'mia', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('non', 'vedo', 'mia', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bolletta', 'su', 'spazio', 'personale'),
#  ('non', 'vedo', 'mia', 'bollette', 'in', 'area', 'riservato'),
#  ('non', 'vedo', 'mia', 'bollette', 'in', 'area', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bollette', 'in', 'area', 'personale'),
#  ('non', 'vedo', 'mia', 'bollette', 'in', 'spazio', 'riservato'),
#  ('non', 'vedo', 'mia', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bollette', 'in', 'spazio', 'personale'),
#  ('non', 'vedo', 'mia', 'bollette', 'su', 'area', 'riservato'),
#  ('non', 'vedo', 'mia', 'bollette', 'su', 'area', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bollette', 'su', 'area', 'personale'),
#  ('non', 'vedo', 'mia', 'bollette', 'su', 'spazio', 'riservato'),
#  ('non', 'vedo', 'mia', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('non', 'vedo', 'mia', 'bollette', 'su', 'spazio', 'personale'),
#  ('non', 'vedo', 'mia', 'fatture', 'in', 'area', 'riservato'),
#  ('non', 'vedo', 'mia', 'fatture', 'in', 'area', 'clienti*'),
#  ('non', 'vedo', 'mia', 'fatture', 'in', 'area', 'personale'),
#  ('non', 'vedo', 'mia', 'fatture', 'in', 'spazio', 'riservato'),
#  ('non', 'vedo', 'mia', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('non', 'vedo', 'mia', 'fatture', 'in', 'spazio', 'personale'),
#  ('non', 'vedo', 'mia', 'fatture', 'su', 'area', 'riservato'),
#  ('non', 'vedo', 'mia', 'fatture', 'su', 'area', 'clienti*'),
#  ('non', 'vedo', 'mia', 'fatture', 'su', 'area', 'personale'),
#  ('non', 'vedo', 'mia', 'fatture', 'su', 'spazio', 'riservato'),
#  ('non', 'vedo', 'mia', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('non', 'vedo', 'mia', 'fatture', 'su', 'spazio', 'personale'),
#  ('non', 'vedo', '', 'bolletta', 'in', 'area', 'riservato'),
#  ('non', 'vedo', '', 'bolletta', 'in', 'area', 'clienti*'),
#  ('non', 'vedo', '', 'bolletta', 'in', 'area', 'personale'),
#  ('non', 'vedo', '', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('non', 'vedo', '', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('non', 'vedo', '', 'bolletta', 'in', 'spazio', 'personale'),
#  ('non', 'vedo', '', 'bolletta', 'su', 'area', 'riservato'),
#  ('non', 'vedo', '', 'bolletta', 'su', 'area', 'clienti*'),
#  ('non', 'vedo', '', 'bolletta', 'su', 'area', 'personale'),
#  ('non', 'vedo', '', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('non', 'vedo', '', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('non', 'vedo', '', 'bolletta', 'su', 'spazio', 'personale'),
#  ('non', 'vedo', '', 'bollette', 'in', 'area', 'riservato'),
#  ('non', 'vedo', '', 'bollette', 'in', 'area', 'clienti*'),
#  ('non', 'vedo', '', 'bollette', 'in', 'area', 'personale'),
#  ('non', 'vedo', '', 'bollette', 'in', 'spazio', 'riservato'),
#  ('non', 'vedo', '', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('non', 'vedo', '', 'bollette', 'in', 'spazio', 'personale'),
#  ('non', 'vedo', '', 'bollette', 'su', 'area', 'riservato'),
#  ('non', 'vedo', '', 'bollette', 'su', 'area', 'clienti*'),
#  ('non', 'vedo', '', 'bollette', 'su', 'area', 'personale'),
#  ('non', 'vedo', '', 'bollette', 'su', 'spazio', 'riservato'),
#  ('non', 'vedo', '', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('non', 'vedo', '', 'bollette', 'su', 'spazio', 'personale'),
#  ('non', 'vedo', '', 'fatture', 'in', 'area', 'riservato'),
#  ('non', 'vedo', '', 'fatture', 'in', 'area', 'clienti*'),
#  ('non', 'vedo', '', 'fatture', 'in', 'area', 'personale'),
#  ('non', 'vedo', '', 'fatture', 'in', 'spazio', 'riservato'),
#  ('non', 'vedo', '', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('non', 'vedo', '', 'fatture', 'in', 'spazio', 'personale'),
#  ('non', 'vedo', '', 'fatture', 'su', 'area', 'riservato'),
#  ('non', 'vedo', '', 'fatture', 'su', 'area', 'clienti*'),
#  ('non', 'vedo', '', 'fatture', 'su', 'area', 'personale'),
#  ('non', 'vedo', '', 'fatture', 'su', 'spazio', 'riservato'),
#  ('non', 'vedo', '', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('non', 'vedo', '', 'fatture', 'su', 'spazio', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'in', 'area', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'in', 'area', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'in', 'area', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'in', 'spazio', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'su', 'area', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'su', 'area', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'su', 'area', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bolletta', 'su', 'spazio', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'in', 'area', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'in', 'area', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'in', 'area', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'in', 'spazio', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'in', 'spazio', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'su', 'area', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'su', 'area', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'su', 'area', 'personale'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'su', 'spazio', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'bollette', 'su', 'spazio', 'personale'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'in', 'area', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'in', 'area', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'in', 'area', 'personale'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'in', 'spazio', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'in', 'spazio', 'personale'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'su', 'area', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'su', 'area', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'su', 'area', 'personale'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'su', 'spazio', 'riservato'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', 'mia', 'fatture', 'su', 'spazio', 'personale'),
#  ('non', 'posso vedere', '', 'bolletta', 'in', 'area', 'riservato'),
#  ('non', 'posso vedere', '', 'bolletta', 'in', 'area', 'clienti*'),
#  ('non', 'posso vedere', '', 'bolletta', 'in', 'area', 'personale'),
#  ('non', 'posso vedere', '', 'bolletta', 'in', 'spazio', 'riservato'),
#  ('non', 'posso vedere', '', 'bolletta', 'in', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', '', 'bolletta', 'in', 'spazio', 'personale'),
#  ('non', 'posso vedere', '', 'bolletta', 'su', 'area', 'riservato'),
#  ('non', 'posso vedere', '', 'bolletta', 'su', 'area', 'clienti*'),
#  ('non', 'posso vedere', '', 'bolletta', 'su', 'area', 'personale'),
#  ('non', 'posso vedere', '', 'bolletta', 'su', 'spazio', 'riservato'),
#  ('non', 'posso vedere', '', 'bolletta', 'su', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', '', 'bolletta', 'su', 'spazio', 'personale'),
#  ('non', 'posso vedere', '', 'bollette', 'in', 'area', 'riservato'),
#  ('non', 'posso vedere', '', 'bollette', 'in', 'area', 'clienti*'),
#  ('non', 'posso vedere', '', 'bollette', 'in', 'area', 'personale'),
#  ('non', 'posso vedere', '', 'bollette', 'in', 'spazio', 'riservato'),
#  ('non', 'posso vedere', '', 'bollette', 'in', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', '', 'bollette', 'in', 'spazio', 'personale'),
#  ('non', 'posso vedere', '', 'bollette', 'su', 'area', 'riservato'),
#  ('non', 'posso vedere', '', 'bollette', 'su', 'area', 'clienti*'),
#  ('non', 'posso vedere', '', 'bollette', 'su', 'area', 'personale'),
#  ('non', 'posso vedere', '', 'bollette', 'su', 'spazio', 'riservato'),
#  ('non', 'posso vedere', '', 'bollette', 'su', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', '', 'bollette', 'su', 'spazio', 'personale'),
#  ('non', 'posso vedere', '', 'fatture', 'in', 'area', 'riservato'),
#  ('non', 'posso vedere', '', 'fatture', 'in', 'area', 'clienti*'),
#  ('non', 'posso vedere', '', 'fatture', 'in', 'area', 'personale'),
#  ('non', 'posso vedere', '', 'fatture', 'in', 'spazio', 'riservato'),
#  ('non', 'posso vedere', '', 'fatture', 'in', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', '', 'fatture', 'in', 'spazio', 'personale'),
#  ('non', 'posso vedere', '', 'fatture', 'su', 'area', 'riservato'),
#  ('non', 'posso vedere', '', 'fatture', 'su', 'area', 'clienti*'),
#  ('non', 'posso vedere', '', 'fatture', 'su', 'area', 'personale'),
#  ('non', 'posso vedere', '', 'fatture', 'su', 'spazio', 'riservato'),
#  ('non', 'posso vedere', '', 'fatture', 'su', 'spazio', 'clienti*'),
#  ('non', 'posso vedere', '', 'fatture', 'su', 'spazio', 'personale')]

# %%
gen_sents = []

for non, trovo, mia, bolletta, su, area, clienti in combos2:
    
    # qui abbiamo due teste, perché il secondo sintagma si accorda alla variabile "area"
    h1 = store(bolletta)
    h2 = store(area)
    
    gen_sents.append(f'{non} {trovo} {h1.article()} {h1.agr(mia)} {h1.word} {h2.preposition(su)} {h2.word} {h2.agr(clienti)}')

# %%
# formatto

gen_sents_format = [formatt(i) for i in gen_sents]

# %% [markdown]
# ### Anche se sono tutte diverse, la ripetitività di queste frasi è ovviamente molto alta, perché il vocabolario di riferimento è piccolo. Potrei volerne prendere solo un subset di 100 frasi

# %%
rd.sample(gen_sents_format, 100)
# Out:
# ["Dove posso vedere le fatture nell'area clienti",
#  'Non trovo la bolletta nello spazio personale',
#  'Dove vedo le mie bollette sullo spazio riservato',
#  "Dove vedo le mie fatture nell'area clienti",
#  'Non posso vedere le bollette sullo spazio riservato',
#  "Dove posso vedere le mie bollette nell'area clienti",
#  'Dove vedo le bollette nello spazio personale',
#  "Non trovo le mie bollette nell'area personale",
#  'Dove vedo la mia bolletta nello spazio clienti',
#  "Dove trovo la bolletta nell'area personale",
#  'Non vedo la bolletta sullo spazio personale',
#  'Dove vedo la mia bolletta nello spazio riservato',
#  'Dove vedo le mie fatture nello spazio personale',
#  "Non posso vedere le bollette sull'area personale",
#  'Non vedo le mie bollette sullo spazio clienti',
#  "Dove posso vedere le mie fatture sull'area riservata",
#  'Dove vedo le mie bollette nello spazio personale',
#  "Non trovo le mie bollette nell'area riservata",
#  'Dove posso vedere la mia bolletta sullo spazio personale',
#  'Dove vedo la bolletta sullo spazio riservato',
#  "Dove vedo le mie fatture nell'area riservata",
#  "Non trovo la bolletta sull'area clienti",
#  "Non posso vedere le mie fatture sull'area clienti",
#  'Non trovo le fatture sullo spazio riservato',
#  "Dove vedo la bolletta sull'area riservata",
#  "Dove posso vedere le mie fatture nell'area clienti",
#  'Non vedo la bolletta nello spazio personale',
#  "Non trovo le fatture nell'area clienti",
#  "Non vedo le mie bollette sull'area clienti",
#  'Dove posso vedere le mie bollette nello spazio personale',
#  "Non vedo la mia bolletta sull'area riservata",
#  'Non posso vedere le bollette nello spazio clienti',
#  'Non trovo le mie bollette sullo spazio riservato',
#  "Dove posso vedere le mie bollette sull'area personale",
#  "Dove trovo le mie fatture sull'area riservata",
#  "Non vedo le mie fatture nell'area personale",
#  'Dove posso vedere la bolletta nello spazio personale',
#  "Non vedo la mia bolletta nell'area clienti",
#  "Dove vedo la bolletta nell'area personale",
#  'Non posso vedere le fatture nello spazio clienti',
#  'Non vedo la bolletta nello spazio riservato',
#  'Non vedo le bollette nello spazio clienti',
#  "Dove trovo le mie fatture sull'area personale",
#  "Non posso vedere la bolletta nell'area riservata",
#  "Non posso vedere le bollette sull'area riservata",
#  "Non trovo la mia bolletta nell'area personale",
#  'Dove trovo le fatture sullo spazio clienti',
#  "Dove trovo le fatture sull'area personale",
#  'Non posso vedere le mie bollette nello spazio personale',
#  'Dove posso vedere le mie fatture nello spazio riservato',
#  "Dove trovo le fatture nell'area clienti",
#  "Non posso vedere le fatture sull'area clienti",
#  "Non vedo le bollette nell'area clienti",
#  'Non posso vedere le mie fatture nello spazio personale',
#  'Non posso vedere la mia bolletta sullo spazio clienti',
#  "Dove vedo le fatture sull'area personale",
#  "Dove posso vedere le mie fatture nell'area personale",
#  "Dove posso vedere le mie fatture nell'area riservata",
#  "Dove vedo le bollette nell'area clienti",
#  'Dove posso vedere la mia bolletta sullo spazio riservato',
#  'Non vedo le fatture nello spazio clienti',
#  "Dove trovo le bollette sull'area clienti",
#  "Non trovo le bollette sull'area clienti",
#  'Non posso vedere la bolletta nello spazio clienti',
#  "Non vedo la bolletta nell'area clienti",
#  'Non posso vedere le fatture nello spazio personale',
#  "Dove trovo le mie bollette sull'area riservata",
#  'Non posso vedere la bolletta nello spazio riservato',
#  'Non vedo le bollette sullo spazio riservato',
#  'Non posso vedere le bollette sullo spazio personale',
#  'Dove posso vedere le fatture nello spazio riservato',
#  'Non posso vedere la mia bolletta nello spazio riservato',
#  "Non posso vedere la bolletta sull'area personale",
#  'Dove trovo le mie fatture nello spazio riservato',
#  'Dove trovo le bollette sullo spazio riservato',
#  'Dove vedo le bollette sullo spazio riservato',
#  'Non trovo la bolletta sullo spazio clienti',
#  'Dove vedo le mie fatture sullo spazio personale',
#  "Non vedo le mie fatture nell'area clienti",
#  'Non trovo le mie bollette nello spazio riservato',
#  "Non posso vedere le mie bollette sull'area clienti",
#  "Non vedo le bollette sull'area riservata",
#  'Non vedo le mie fatture nello spazio riservato',
#  "Dove posso vedere le fatture sull'area riservata",
#  'Non vedo la bolletta nello spazio clienti',
#  'Non vedo le fatture sullo spazio clienti',
#  "Non vedo la mia bolletta nell'area personale",
#  'Non vedo le bollette sullo spazio clienti',
#  "Dove vedo le mie fatture sull'area personale",
#  'Dove posso vedere le mie bollette sullo spazio riservato',
#  'Non vedo le fatture nello spazio riservato',
#  "Non vedo le bollette sull'area clienti",
#  "Dove trovo le mie fatture sull'area clienti",
#  "Dove vedo le mie bollette sull'area riservata",
#  "Dove posso vedere le mie bollette sull'area riservata",
#  'Dove posso vedere la bolletta sullo spazio personale',
#  'Dove trovo la bolletta nello spazio riservato',
#  'Non trovo le mie fatture sullo spazio clienti',
#  'Non vedo la mia bolletta nello spazio riservato',
#  "Non vedo la mia bolletta nell'area riservata"]
